# %%
# !pip install cryptography
from cryptography.hazmat.primitives import serialization
from cryptography.hazmat.backends import default_backend
import base64
from cryptography.hazmat.primitives import hashes
from cryptography.hazmat.primitives.asymmetric import padding, rsa
from cryptography.exceptions import InvalidSignature
from pathlib import Path
import os
from cryptography.hazmat.backends import default_backend
import requests
import datetime
# Cell 1 — load KALSHI keys from .env in the same directory as this notebook


# --- Try to use python-dotenv if it's installed (recommended) ---
try:
    from dotenv import load_dotenv  # pip install python-dotenv
    env_path = Path.cwd() / ".env"   # assumes notebook is run from the same directory as .env
    if not env_path.exists():
        raise FileNotFoundError(f".env not found at: {env_path}")
    load_dotenv(dotenv_path=env_path, override=False)
except ImportError:
    # --- Fallback: minimal .env parser (no extra install needed) ---
    env_path = Path.cwd() / ".env"
    if not env_path.exists():
        raise FileNotFoundError(f".env not found at: {env_path}")

    for line in env_path.read_text().splitlines():
        line = line.strip()
        if not line or line.startswith("#") or "=" not in line:
            continue
        k, v = line.split("=", 1)
        k = k.strip()
        v = v.strip().strip('"').strip("'")
        os.environ.setdefault(k, v)  # don't overwrite if already set

# --- Read your keys into variables ---
public_key = os.getenv("KALSHI-ACCESS-KEY-DEMO")

missing = [k for k, v in {
    "KALSHI-ACCESS-KEY": public_key
}.items() if not v]

if missing:
    raise KeyError(f"Missing env var(s): {missing}. Check your .env formatting and key names.")

print("Loaded Kalshi keys ✅")  # intentionally not printing the secret values


def load_private_key_from_file(file_path):
    with open(file_path, "rb") as key_file:
        private_key = serialization.load_pem_private_key(
            key_file.read(),
            password=None,  # or provide a password if your key is encrypted
            backend=default_backend()
        )
    return private_key


def sign_pss_text(private_key: rsa.RSAPrivateKey, text: str) -> str:
    message = text.encode('utf-8')
    try:
        signature = private_key.sign(
            message,
            padding.PSS(
                mgf=padding.MGF1(hashes.SHA256()),
                salt_length=padding.PSS.DIGEST_LENGTH
            ),
            hashes.SHA256()
        )
        return base64.b64encode(signature).decode('utf-8')
    except InvalidSignature as e:
        raise ValueError("RSA sign PSS failed") from e
    

def make_authenticated_request(path, method='GET', params=None):
    """Make an authenticated request to Kalshi demo API."""
    current_time = datetime.datetime.now()
    timestamp = current_time.timestamp()
    current_time_milliseconds = int(timestamp * 1000)
    timestamp_str = str(current_time_milliseconds)
    
    private_key = load_private_key_from_file('pbhaskarademo.txt')
    
    base_url = 'https://demo-api.kalshi.co'
    
    # Strip query parameters from path before signing
    path_without_query = path.split('?')[0]
    msg_string = timestamp_str + method + path_without_query
    sig = sign_pss_text(private_key, msg_string)
    
    headers = {
        'KALSHI-ACCESS-KEY': public_key,
        'KALSHI-ACCESS-SIGNATURE': sig,
        'KALSHI-ACCESS-TIMESTAMP': timestamp_str
    }
    
    if method == 'GET':
        response = requests.get(base_url + path, headers=headers, params=params)
    else:
        response = requests.post(base_url + path, headers=headers, json=params)
    
    return response
# Out:
# Requirement already satisfied: cryptography in /opt/anaconda3/lib/python3.12/site-packages (43.0.0)
# Requirement already satisfied: cffi>=1.12 in /opt/anaconda3/lib/python3.12/site-packages (from cryptography) (1.17.1)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.12/site-packages (from cffi>=1.12->cryptography) (2.21)
# Loaded Kalshi keys ✅

# %%
# Fed & Jerome Powell Markets Analysis

This notebook fetches and analyzes all Kalshi prediction markets related to:
- Federal Reserve (Fed)
- Jerome Powell
- Federal Reserve policy decisions

## Analysis Includes:
- Market category
- Liquidity (trading volume)
- Market duration
- Results with winner information for multi-decision events
- Complete market details and statistics

# %%
# ============================================================================
# FETCH FED & JEROME POWELL RELATED MARKETS
# ============================================================================

import time
from datetime import datetime, timedelta, timezone

print("="*80)
print("FETCHING FED & JEROME POWELL RELATED MARKETS")
print("="*80)

# Calculate time window (past year)
now = datetime.now(timezone.utc)
one_year_ago = now - timedelta(days=365)
min_close_ts = int(one_year_ago.timestamp())
max_close_ts = int(now.timestamp())

print(f"\nTime window:")
print(f"  From: {one_year_ago.strftime('%Y-%m-%d %H:%M:%S UTC')}")
print(f"  To:   {now.strftime('%Y-%m-%d %H:%M:%S UTC')}")

base_url = "https://api.elections.kalshi.com/trade-api/v2"

# Search keywords for Fed/Powell related markets
search_keywords = [
    "fed", "federal reserve", "jerome powell", "powell", 
    "fomc", "federal funds", "interest rate", "fed decision",
    "monetary policy", "fed chair"
]

print(f"\nSearching for markets with keywords: {', '.join(search_keywords)}")
print("\nFetching all series first...")

# Fetch all series
all_series = []
try:
    response = requests.get(f"{base_url}/series", params={"limit": 200})
    if response.status_code == 200:
        all_series = response.json().get('series', [])
        print(f"  ✓ Found {len(all_series)} total series")
    time.sleep(0.5)
except Exception as e:
    print(f"  ✗ Error: {e}")

# Filter series that match our keywords
fed_series = []
for series in all_series:
    title = series.get('title', '').lower()
    ticker = series.get('ticker', '').lower()
    
    for keyword in search_keywords:
        if keyword.lower() in title or keyword.lower() in ticker:
            fed_series.append(series)
            break

print(f"\n✓ Found {len(fed_series)} Fed/Powell related series:")
for s in fed_series[:10]:
    print(f"  - {s['ticker']}: {s['title']}")
if len(fed_series) > 10:
    print(f"  ... and {len(fed_series) - 10} more")

# Fetch all markets from these series
print(f"\nFetching markets from {len(fed_series)} series...")
all_fed_markets = []

for i, series in enumerate(fed_series, 1):
    series_ticker = series['ticker']
    cursor = None
    series_markets = []
    
    while True:
        params = {
            "series_ticker": series_ticker,
            "status": "settled",
            "min_close_ts": min_close_ts,
            "max_close_ts": max_close_ts,
            "limit": 1000
        }
        
        if cursor:
            params["cursor"] = cursor
        
        try:
            response = requests.get(f"{base_url}/markets", params=params)
            
            if response.status_code == 429:
                time.sleep(2)
                continue
            
            if response.status_code != 200:
                break
            
            data = response.json()
            markets = data.get('markets', [])
            series_markets.extend(markets)
            
            cursor = data.get('cursor')
            if not cursor:
                break
            
            time.sleep(0.3)
            
        except:
            break
    
    if series_markets:
        all_fed_markets.extend(series_markets)
        print(f"  [{i}/{len(fed_series)}] {series_ticker}: {len(series_markets)} markets")

print(f"\n{'='*80}")
print(f"✓ TOTAL FED/POWELL MARKETS: {len(all_fed_markets)}")
print(f"{'='*80}")

all_markets = all_fed_markets
# Out:
# ================================================================================
# FETCHING FED & JEROME POWELL RELATED MARKETS
# ================================================================================
#
# Time window:
#   From: 2025-02-02 00:09:00 UTC
#   To:   2026-02-02 00:09:00 UTC
#
# Searching for markets with keywords: fed, federal reserve, jerome powell, powell, fomc, federal funds, interest rate, fed decision, monetary policy, fed chair
#
# Fetching all series first...
#   ✓ Found 8222 total series
#
# ✓ Found 97 Fed/Powell related series:
#   - KXFEDDCEXT: Extending Federal Takeover of DC
#   - KXCBDECISIONJAPAN: Bank Of Japan policy interest rate decision
#   - KXFEDCONF: Powell confirmation
#   - FEDDECISION: Fed meeting
#   - FEDCONF: Powell confirmation
#   - TAPER: Fed tapering
#   - RATEHIKE: Number of Fed rate hikes
#   - FEDMEET: Fed emergency meeting
#   - RATECUT: Fed rate cut
#   - KXLOWESTRATE: Fed funds lowest rate
#   ... and 87 more
#
# Fetching markets from 97 series...
#   [1/97] KXFEDDCEXT: 1 markets
#   [2/97] KXCBDECISIONJAPAN: 12 markets
#   [14/97] KXBALANCESHEET: 2 markets
#   [15/97] KXPOWELLMENTION: 142 markets
#   [16/97] KXFEDGOVNOM: 6 markets
#   [17/97] KXCONFFEDGOV: 20 markets
#   [18/97] KXCBDECISIONAUSTRALIA: 5 markets
#   [22/97] KXJACKSMITHCHARGE: 1 markets
#   [26/97] KXFEDMENTION: 290 markets
#   [28/97] KXPRESNOMFEDCHAIR: 10 markets
#   [29/97] KXCOOKCHARGE: 1 markets
#   [32/97] KXDOTPLOT: 2 markets
#   [34/97] KXEARNINGSMENTIONFDX: 44 markets
#   [35/97] KXFTC: 4 markets
#   [38/97] KXLEAVEPOWELL: 5 markets
#   [40/97] KXFEDCOMBO: 8 markets
#   [44/97] KXARRESTPOWELL: 1 markets
#   [46/97] KXTRUMPPOW: 1 markets
#   [47/97] KXCBDECISIONCHINA: 15 markets
#   [49/97] KXCBDECISIONENGLAND: 5 markets
#   [50/97] KXGOVAPPTCOUNT: 4 markets
#   [58/97] KXFED: 88 markets
#   [59/97] KXFOMCDISSENTCOUNT: 15 markets
#   [62/97] KXFOMCVOTE: 3 markets
#   [64/97] KXCBDECISIONEU: 5 markets
#   [65/97] KXFEDHIKE: 1 markets
#   [69/97] KXFEDDECISION: 40 markets
#   [71/97] KXFEDERALCHARGE: 1 markets
#   [73/97] KXSCHIFFCHARGE: 1 markets
#   [75/97] KXCBDECISIONMEXICO: 5 markets
#   [76/97] KXCBDECISIONCANADA: 15 markets
#   [77/97] KXJPOWMENTION: 54 markets
#   [80/97] KXGOVREOPEN2025: 1 markets
#   [82/97] KXFEDRATEMIN: 3 markets
#   [84/97] KXFEDEMPLOYEES: 5 markets
#   [86/97] KXFEDGOVMENTION: 11 markets
#   [87/97] KXBOARD: 9 markets
#   [89/97] KXFEDFACILITY: 1 markets
#   [91/97] KXFEDWIKI: 1 markets
#   [93/97] KXTRYFIREPOWELL: 1 markets
#   [94/97] KXFEDMEET: 1 markets
#   [96/97] KXFEDDISSENT: 12 markets
#   [97/97] KXCBDECISIONKOREA: 5 markets
#
# ================================================================================
# ✓ TOTAL FED/POWELL MARKETS: 857
# ================================================================================

# %%
# ============================================================================
# ANALYZE AND DISPLAY ALL FED/POWELL MARKETS
# ============================================================================

print("\n" + "="*80)
print("ALL FED & JEROME POWELL MARKETS")
print("="*80)

# Extract volume and create event mapping
markets_with_details = []
event_to_markets = {}

for market in all_markets:
    try:
        # Try to get volume - this is the total traded, not current liquidity
        volume = float(market.get('volume', '0'))
        liquidity = float(market.get('liquidity_dollars', '0'))
        
        # Calculate duration
        open_time = datetime.fromisoformat(market['open_time'].replace('Z', '+00:00'))
        close_time = datetime.fromisoformat(market['close_time'].replace('Z', '+00:00'))
        duration_days = (close_time - open_time).total_seconds() / (3600 * 24)
        
        event_ticker = market.get('event_ticker', market['ticker'])
        
        # Track markets by event for multi-decision resolution
        if event_ticker not in event_to_markets:
            event_to_markets[event_ticker] = []
        event_to_markets[event_ticker].append(market)
        
        markets_with_details.append({
            'ticker': market['ticker'],
            'title': market.get('title', 'N/A'),
            'category': market.get('category', 'N/A'),
            'volume': volume,
            'liquidity': liquidity,
            'result': market.get('result', 'N/A'),
            'duration_days': duration_days,
            'event_ticker': event_ticker,
            'open_time': open_time,
            'close_time': close_time
        })
    except:
        continue

# Sort by volume descending (not liquidity)
markets_with_details.sort(key=lambda x: x['volume'], reverse=True)

# Display all markets
print(f"\nTotal markets found: {len(markets_with_details)}")
print("\n")

for i, market in enumerate(markets_with_details, 1):
    print(f"\n{'='*100}")
    print(f"Market #{i}")
    print(f"{'='*100}")
    print(f"  Category:     {market['category']}")
    print(f"  Ticker:       {market['ticker']}")
    print(f"  Title:        {market['title']}")
    print(f"  Volume:       ${market['volume']:,.2f}")
    print(f"  Liquidity:    ${market['liquidity']:,.2f}")
    print(f"  Duration:     {market['duration_days']:.1f} days")
    print(f"  Open Date:    {market['open_time'].strftime('%Y-%m-%d')}")
    print(f"  Close Date:   {market['close_time'].strftime('%Y-%m-%d')}")
    
    # Enhanced result display for multi-decision markets
    result_str = market['result'].upper()
    
    # Check if this is part of a multi-decision event
    event_markets = event_to_markets.get(market['event_ticker'], [])
    if len(event_markets) > 1:
        # Find the winning market in this event
        winners = [m for m in event_markets if m.get('result') == 'yes']
        
        if winners:
            if market['result'] == 'yes':
                result_str = f"YES (This option won)"
            else:
                # Show which option actually won
                winner_tickers = [w['ticker'] for w in winners]
                result_str = f"NO (Winner(s): {', '.join(winner_tickers[:3])})"
        else:
            result_str = f"{result_str} (Multi-decision event, no clear winner found)"
    
    print(f"  Result:       {result_str}")
    print(f"  Event Type:   {'Multi-decision' if len(event_markets) > 1 else 'Binary'} ({len(event_markets)} option(s))")

print("\n" + "="*100)
print("\nSUMMARY STATISTICS")
print("="*100)
print(f"  Total markets:     {len(markets_with_details):,}")
print(f"  Average volume:    ${sum(m['volume'] for m in markets_with_details)/len(markets_with_details):,.2f}")
print(f"  Average duration:  {sum(m['duration_days'] for m in markets_with_details)/len(markets_with_details):.1f} days")
print(f"  Total volume:      ${sum(m['volume'] for m in markets_with_details):,.2f}")

# Show category distribution
category_counts = {}
for m in markets_with_details:
    cat = m['category']
    category_counts[cat] = category_counts.get(cat, 0) + 1

print(f"\n  Category Distribution:")
for cat, count in sorted(category_counts.items(), key=lambda x: x[1], reverse=True):
    print(f"    {cat}: {count} markets")

# Show result distribution
result_counts = {}
for m in markets_with_details:
    result = m['result']
    result_counts[result] = result_counts.get(result, 0) + 1

print(f"\n  Result Distribution:")
for result, count in sorted(result_counts.items(), key=lambda x: x[1], reverse=True):
    print(f"    {result}: {count} markets")

# Show multi-decision vs binary breakdown
multi_count = sum(1 for m in markets_with_details if len(event_to_markets.get(m['event_ticker'], [])) > 1)
print(f"\n  Market Types:")
print(f"    Multi-decision: {multi_count}")
print(f"    Binary: {len(markets_with_details) - multi_count}")

# Top 10 by volume
print(f"\n{'='*100}")
print("TOP 10 BY VOLUME")
print("="*100)
for i, m in enumerate(markets_with_details[:10], 1):
    print(f"\n  {i}. {m['ticker']}")
    print(f"     Volume: ${m['volume']:,.2f}")
    print(f"     Title: {m['title']}")

print("="*100)
# Out:
# ================================================================================
# ALL FED & JEROME POWELL MARKETS
# ================================================================================
#
# Total markets found: 857
#
#
#
# ====================================================================================================
# Market #1
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDDECISION-25SEP-H0
#   Title:        Will the Federal Reserve Hike rates by 0bps at their September 2025 meeting?
#   Volume:       $42,718,863.00
#   Liquidity:    $16,439.15
#   Duration:     49.2 days
#   Open Date:    2025-07-30
#   Close Date:   2025-09-17
#   Result:       NO (Winner(s): KXFEDDECISION-25SEP-C25)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #2
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDDECISION-25SEP-C26
#   Title:        Will the Federal Reserve Cut rates by >25bps at their September 2025 meeting?
#   Volume:       $29,261,331.00
#   Liquidity:    $0.00
#   Duration:     49.2 days
#   Open Date:    2025-07-30
#   Close Date:   2025-09-17
#   Result:       NO (Winner(s): KXFEDDECISION-25SEP-C25)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #3
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDDECISION-25JUL-C25
#   Title:        Will the Federal Reserve Cut rates by 25bps at their July 2025 meeting?
#   Volume:       $20,535,325.00
#   Liquidity:    $0.00
#   Duration:     42.2 days
#   Open Date:    2025-06-18
#   Close Date:   2025-07-30
#   Result:       NO (Winner(s): KXFEDDECISION-25JUL-H0)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #4
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDDECISION-26JAN-C25
#   Title:        Will the Federal Reserve Cut rates by 25bps at their January 2026 meeting?
#   Volume:       $18,466,757.00
#   Liquidity:    $-163.98
#   Duration:     121.2 days
#   Open Date:    2025-09-29
#   Close Date:   2026-01-28
#   Result:       NO (Winner(s): KXFEDDECISION-26JAN-H0)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #5
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDDECISION-25SEP-C25
#   Title:        Will the Federal Reserve Cut rates by 25bps at their September 2025 meeting?
#   Volume:       $18,168,848.00
#   Liquidity:    $60,799.12
#   Duration:     49.2 days
#   Open Date:    2025-07-30
#   Close Date:   2025-09-17
#   Result:       YES (This option won)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #6
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDDECISION-25MAY-C25
#   Title:        Will the Federal Reserve Cut rates by 25bps at their May 2025 meeting?
#   Volume:       $17,739,576.00
#   Liquidity:    $1,374.08
#   Duration:     49.2 days
#   Open Date:    2025-03-19
#   Close Date:   2025-05-07
#   Result:       NO (Winner(s): KXFEDDECISION-25MAY-H0)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #7
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDDECISION-25JUN-C25
#   Title:        Will the Federal Reserve Cut rates by 25bps at their June 2025 meeting?
#   Volume:       $17,062,008.00
#   Liquidity:    $10,344.26
#   Duration:     42.2 days
#   Open Date:    2025-05-07
#   Close Date:   2025-06-18
#   Result:       NO (Winner(s): KXFEDDECISION-25JUN-H0)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #8
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDDECISION-25DEC-H0
#   Title:        Will the Federal Reserve Hike rates by 0bps at their December 2025 meeting?
#   Volume:       $15,760,947.00
#   Liquidity:    $3,724.95
#   Duration:     127.2 days
#   Open Date:    2025-08-05
#   Close Date:   2025-12-10
#   Result:       NO (Winner(s): KXFEDDECISION-25DEC-C25)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #9
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDDECISION-25OCT-H0
#   Title:        Will the Federal Reserve Hike rates by 0bps at their October 2025 meeting?
#   Volume:       $15,137,495.00
#   Liquidity:    $18,748.13
#   Duration:     85.2 days
#   Open Date:    2025-08-05
#   Close Date:   2025-10-29
#   Result:       NO (Winner(s): KXFEDDECISION-25OCT-C25)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #10
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDDECISION-25JUL-H0
#   Title:        Will the Federal Reserve Hike rates by 0bps at their July 2025 meeting?
#   Volume:       $15,032,203.00
#   Liquidity:    $0.00
#   Duration:     42.2 days
#   Open Date:    2025-06-18
#   Close Date:   2025-07-30
#   Result:       YES (This option won)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #11
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDDECISION-25OCT-C26
#   Title:        Will the Federal Reserve Cut rates by >25bps at their October 2025 meeting?
#   Volume:       $13,693,429.00
#   Liquidity:    $6,594.87
#   Duration:     85.2 days
#   Open Date:    2025-08-05
#   Close Date:   2025-10-29
#   Result:       NO (Winner(s): KXFEDDECISION-25OCT-C25)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #12
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDDECISION-25MAY-H0
#   Title:        Will the Federal Reserve Hike rates by 0bps at their May 2025 meeting?
#   Volume:       $13,237,803.00
#   Liquidity:    $24,671.35
#   Duration:     49.2 days
#   Open Date:    2025-03-19
#   Close Date:   2025-05-07
#   Result:       YES (This option won)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #13
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDDECISION-25JUN-H0
#   Title:        Will the Federal Reserve Hike rates by 0bps at their June 2025 meeting?
#   Volume:       $12,292,142.00
#   Liquidity:    $0.00
#   Duration:     42.2 days
#   Open Date:    2025-05-07
#   Close Date:   2025-06-18
#   Result:       YES (This option won)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #14
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDDECISION-25DEC-C25
#   Title:        Will the Federal Reserve Cut rates by 25bps at their December 2025 meeting?
#   Volume:       $12,184,561.00
#   Liquidity:    $6,505.66
#   Duration:     127.2 days
#   Open Date:    2025-08-05
#   Close Date:   2025-12-10
#   Result:       YES (This option won)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #15
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDDECISION-25JUL-C26
#   Title:        Will the Federal Reserve Cut rates by >25bps at their July 2025 meeting?
#   Volume:       $11,766,116.00
#   Liquidity:    $0.00
#   Duration:     42.2 days
#   Open Date:    2025-06-18
#   Close Date:   2025-07-30
#   Result:       NO (Winner(s): KXFEDDECISION-25JUL-H0)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #16
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDDECISION-25DEC-C26
#   Title:        Will the Federal Reserve Cut rates by >25bps at their December 2025 meeting?
#   Volume:       $11,614,979.00
#   Liquidity:    $4,050.09
#   Duration:     127.2 days
#   Open Date:    2025-08-05
#   Close Date:   2025-12-10
#   Result:       NO (Winner(s): KXFEDDECISION-25DEC-C25)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #17
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDDECISION-26JAN-H0
#   Title:        Will the Federal Reserve Hike rates by 0bps at their January 2026 meeting?
#   Volume:       $10,488,486.00
#   Liquidity:    $-23.00
#   Duration:     121.2 days
#   Open Date:    2025-09-29
#   Close Date:   2026-01-28
#   Result:       YES (This option won)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #18
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDDECISION-25OCT-C25
#   Title:        Will the Federal Reserve Cut rates by 25bps at their October 2025 meeting?
#   Volume:       $9,914,224.00
#   Liquidity:    $28,431.55
#   Duration:     85.2 days
#   Open Date:    2025-08-05
#   Close Date:   2025-10-29
#   Result:       YES (This option won)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #19
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDDECISION-25MAY-C26
#   Title:        Will the Federal Reserve Cut rates by >25bps at their May 2025 meeting?
#   Volume:       $7,617,148.00
#   Liquidity:    $0.00
#   Duration:     49.2 days
#   Open Date:    2025-03-19
#   Close Date:   2025-05-07
#   Result:       NO (Winner(s): KXFEDDECISION-25MAY-H0)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #20
# ====================================================================================================
#   Category:     N/A
#   Ticker:       LEAVEPOWELL-25-DEC31
#   Title:        Powell leaves before 2026?
#   Volume:       $6,457,024.00
#   Liquidity:    $43,367.45
#   Duration:     609.7 days
#   Open Date:    2024-05-01
#   Close Date:   2026-01-01
#   Result:       NO (Multi-decision event, no clear winner found)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #21
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDDECISION-25JUN-C26
#   Title:        Will the Federal Reserve Cut rates by >25bps at their June 2025 meeting?
#   Volume:       $6,007,639.00
#   Liquidity:    $0.00
#   Duration:     42.2 days
#   Open Date:    2025-05-07
#   Close Date:   2025-06-18
#   Result:       NO (Winner(s): KXFEDDECISION-25JUN-H0)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #22
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDDECISION-26JAN-C26
#   Title:        Will the Federal Reserve Cut rates by >25bps at their January 2026 meeting?
#   Volume:       $5,268,472.00
#   Liquidity:    $-6,934.27
#   Duration:     121.2 days
#   Open Date:    2025-09-29
#   Close Date:   2026-01-28
#   Result:       NO (Winner(s): KXFEDDECISION-26JAN-H0)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #23
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXGOVREOPEN2025-26JAN01
#   Title:        Will the federal government shut down for fewer than 92 days?
#   Volume:       $4,205,749.00
#   Liquidity:    $0.00
#   Duration:     18.0 days
#   Open Date:    2025-10-26
#   Close Date:   2025-11-13
#   Result:       YES
#   Event Type:   Binary (1 option(s))
#
# ====================================================================================================
# Market #24
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXPRESNOMFEDCHAIR-25-26FEB
#   Title:        Will Trump announce his new Chair of the Federal Reserve in 2026?
#   Volume:       $3,938,536.00
#   Liquidity:    $0.00
#   Duration:     58.9 days
#   Open Date:    2025-12-02
#   Close Date:   2026-01-30
#   Result:       YES (This option won)
#   Event Type:   Multi-decision (10 option(s))
#
# ====================================================================================================
# Market #25
# ====================================================================================================
#   Category:     N/A
#   Ticker:       FED-25MAY-T4.25
#   Title:        Will the upper bound of the federal funds rate be above 4.25% following the Fed's May 7, 2025 meeting?
#   Volume:       $3,745,708.00
#   Liquidity:    $5,991.32
#   Duration:     259.2 days
#   Open Date:    2024-08-21
#   Close Date:   2025-05-07
#   Result:       YES (This option won)
#   Event Type:   Multi-decision (11 option(s))
#
# ====================================================================================================
# Market #26
# ====================================================================================================
#   Category:     N/A
#   Ticker:       FED-25MAY-T4.00
#   Title:        Will the upper bound of the federal funds rate be above 4.00% following the Fed's May 7, 2025 meeting?
#   Volume:       $2,691,205.00
#   Liquidity:    $8,875.55
#   Duration:     259.2 days
#   Open Date:    2024-08-21
#   Close Date:   2025-05-07
#   Result:       YES (This option won)
#   Event Type:   Multi-decision (11 option(s))
#
# ====================================================================================================
# Market #27
# ====================================================================================================
#   Category:     N/A
#   Ticker:       FED-25SEP-T4.25
#   Title:        Will the upper bound of the federal funds rate be above 4.25% following the Fed's Sep 17, 2025 meeting?
#   Volume:       $2,182,903.00
#   Liquidity:    $170,132.78
#   Duration:     392.2 days
#   Open Date:    2024-08-21
#   Close Date:   2025-09-17
#   Result:       NO (Winner(s): FED-25SEP-T4.00, FED-25SEP-T3.75, FED-25SEP-T3.50)
#   Event Type:   Multi-decision (11 option(s))
#
# ====================================================================================================
# Market #28
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDDECISION-25MAY-H25
#   Title:        Will the Federal Reserve Hike rates by 25bps at their May 2025 meeting?
#   Volume:       $2,008,280.00
#   Liquidity:    $49,487.32
#   Duration:     49.2 days
#   Open Date:    2025-03-19
#   Close Date:   2025-05-07
#   Result:       NO (Winner(s): KXFEDDECISION-25MAY-H0)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #29
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXPRESNOMFEDCHAIR-25
#   Title:        Will Trump announce his new Chair of the Federal Reserve in 2025?
#   Volume:       $1,504,159.00
#   Liquidity:    $38.94
#   Duration:     176.2 days
#   Open Date:    2025-07-09
#   Close Date:   2026-01-01
#   Result:       NO (Winner(s): KXPRESNOMFEDCHAIR-25-26MAR16, KXPRESNOMFEDCHAIR-25-26MAR01, KXPRESNOMFEDCHAIR-25-26FEB15)
#   Event Type:   Multi-decision (10 option(s))
#
# ====================================================================================================
# Market #30
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDDECISION-26JAN-H25
#   Title:        Will the Federal Reserve Hike rates by 25bps at their January 2026 meeting?
#   Volume:       $1,462,769.00
#   Liquidity:    $0.00
#   Duration:     121.2 days
#   Open Date:    2025-09-29
#   Close Date:   2026-01-28
#   Result:       NO (Winner(s): KXFEDDECISION-26JAN-H0)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #31
# ====================================================================================================
#   Category:     N/A
#   Ticker:       LEAVEPOWELL-25-AUG31
#   Title:        Powell leaves before 2025?
#   Volume:       $1,324,130.00
#   Liquidity:    $10,150.00
#   Duration:     40.4 days
#   Open Date:    2025-07-22
#   Close Date:   2025-09-01
#   Result:       NO (Multi-decision event, no clear winner found)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #32
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDDECISION-25MAR-H0
#   Title:        Will the Federal Reserve Hike rates by 0bps at their March 2025 meeting?
#   Volume:       $1,322,446.00
#   Liquidity:    $0.00
#   Duration:     49.1 days
#   Open Date:    2025-01-29
#   Close Date:   2025-03-19
#   Result:       YES (This option won)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #33
# ====================================================================================================
#   Category:     N/A
#   Ticker:       FED-25JUL-T4.25
#   Title:        Will the upper bound of the federal funds rate be above 4.25% following the Fed's Jul 30, 2025 meeting?
#   Volume:       $1,283,855.00
#   Liquidity:    $133.43
#   Duration:     343.2 days
#   Open Date:    2024-08-21
#   Close Date:   2025-07-30
#   Result:       YES (This option won)
#   Event Type:   Multi-decision (11 option(s))
#
# ====================================================================================================
# Market #34
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDDECISION-25SEP-H25
#   Title:        Will the Federal Reserve Hike rates by 25bps at their September 2025 meeting?
#   Volume:       $1,144,857.00
#   Liquidity:    $0.00
#   Duration:     49.2 days
#   Open Date:    2025-07-30
#   Close Date:   2025-09-17
#   Result:       NO (Winner(s): KXFEDDECISION-25SEP-C25)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #35
# ====================================================================================================
#   Category:     N/A
#   Ticker:       FED-25SEP-T4.00
#   Title:        Will the upper bound of the federal funds rate be above 4.00% following the Fed's Sep 17, 2025 meeting?
#   Volume:       $983,052.00
#   Liquidity:    $35,556.60
#   Duration:     392.2 days
#   Open Date:    2024-08-21
#   Close Date:   2025-09-17
#   Result:       YES (This option won)
#   Event Type:   Multi-decision (11 option(s))
#
# ====================================================================================================
# Market #36
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDDECISION-25MAR-C25
#   Title:        Will the Federal Reserve Cut rates by 25bps at their March 2025 meeting?
#   Volume:       $944,579.00
#   Liquidity:    $0.47
#   Duration:     49.1 days
#   Open Date:    2025-01-29
#   Close Date:   2025-03-19
#   Result:       NO (Winner(s): KXFEDDECISION-25MAR-H0)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #37
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDDECISION-25JUN-H25
#   Title:        Will the Federal Reserve Hike rates by 25bps at their June 2025 meeting?
#   Volume:       $911,763.00
#   Liquidity:    $0.00
#   Duration:     42.2 days
#   Open Date:    2025-05-07
#   Close Date:   2025-06-18
#   Result:       NO (Winner(s): KXFEDDECISION-25JUN-H0)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #38
# ====================================================================================================
#   Category:     N/A
#   Ticker:       FED-25DEC-T3.75
#   Title:        Will the upper bound of the federal funds rate be above 3.75% following the Fed's Dec 10, 2025 meeting?
#   Volume:       $804,003.00
#   Liquidity:    $-196.05
#   Duration:     476.2 days
#   Open Date:    2024-08-21
#   Close Date:   2025-12-10
#   Result:       NO (Winner(s): FED-25DEC-T3.50, FED-25DEC-T3.25, FED-25DEC-T3.00)
#   Event Type:   Multi-decision (11 option(s))
#
# ====================================================================================================
# Market #39
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFED-26JAN-T3.75
#   Title:        Will the upper bound of the federal funds rate be above 3.75% following the Fed's Jan 28, 2026 meeting?
#   Volume:       $781,834.00
#   Liquidity:    $-1,917.60
#   Duration:     175.2 days
#   Open Date:    2025-08-06
#   Close Date:   2026-01-28
#   Result:       NO (Winner(s): KXFED-26JAN-T3.50, KXFED-26JAN-T3.25, KXFED-26JAN-T3.00)
#   Event Type:   Multi-decision (11 option(s))
#
# ====================================================================================================
# Market #40
# ====================================================================================================
#   Category:     N/A
#   Ticker:       FED-25JUN-T4.25
#   Title:        Will the upper bound of the federal funds rate be above 4.25% following the Fed's Jun 18, 2025 meeting?
#   Volume:       $747,523.00
#   Liquidity:    $0.00
#   Duration:     301.2 days
#   Open Date:    2024-08-21
#   Close Date:   2025-06-18
#   Result:       YES (This option won)
#   Event Type:   Multi-decision (11 option(s))
#
# ====================================================================================================
# Market #41
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDDECISION-25MAY-H26
#   Title:        Will the Federal Reserve Hike rates by >25bps at their May 2025 meeting?
#   Volume:       $740,332.00
#   Liquidity:    $0.00
#   Duration:     49.2 days
#   Open Date:    2025-03-19
#   Close Date:   2025-05-07
#   Result:       NO (Winner(s): KXFEDDECISION-25MAY-H0)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #42
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXPRESNOMFEDCHAIR-25-26FEB15
#   Title:        Will Trump announce his new Chair of the Federal Reserve in 2026?
#   Volume:       $701,291.00
#   Liquidity:    $0.00
#   Duration:     27.1 days
#   Open Date:    2026-01-03
#   Close Date:   2026-01-30
#   Result:       YES (This option won)
#   Event Type:   Multi-decision (10 option(s))
#
# ====================================================================================================
# Market #43
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDMEET-25-JAN01
#   Title:        Will the Fed have an emergency meeting before Jan 1, 2026?
#   Volume:       $607,573.00
#   Liquidity:    $-52.50
#   Duration:     421.6 days
#   Open Date:    2024-11-05
#   Close Date:   2026-01-01
#   Result:       NO
#   Event Type:   Binary (1 option(s))
#
# ====================================================================================================
# Market #44
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDDECISION-25JUL-H25
#   Title:        Will the Federal Reserve Hike rates by 25bps at their July 2025 meeting?
#   Volume:       $558,764.00
#   Liquidity:    $20.00
#   Duration:     42.2 days
#   Open Date:    2025-06-18
#   Close Date:   2025-07-30
#   Result:       NO (Winner(s): KXFEDDECISION-25JUL-H0)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #45
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDDECISION-25SEP-H26
#   Title:        Will the Federal Reserve Hike rates by >25bps at their September 2025 meeting?
#   Volume:       $525,757.00
#   Liquidity:    $0.00
#   Duration:     49.2 days
#   Open Date:    2025-07-30
#   Close Date:   2025-09-17
#   Result:       NO (Winner(s): KXFEDDECISION-25SEP-C25)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #46
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDEMPLOYEES-26JAN-250000
#   Title:        Will there be more than 250000 government employees cut before Jan 2026?
#   Volume:       $521,022.00
#   Liquidity:    $3,079.99
#   Duration:     399.0 days
#   Open Date:    2024-11-12
#   Close Date:   2025-12-16
#   Result:       YES (This option won)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #47
# ====================================================================================================
#   Category:     N/A
#   Ticker:       FEDHIKE-25DEC31
#   Title:        Will the Federal Reserve hike rates by December 31, 2025?
#   Volume:       $519,780.00
#   Liquidity:    $-17.37
#   Duration:     748.3 days
#   Open Date:    2023-12-14
#   Close Date:   2026-01-01
#   Result:       NO
#   Event Type:   Binary (1 option(s))
#
# ====================================================================================================
# Market #48
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDCOMBO-26JAN-25C-T0
#   Title:        Will Federal Funds Rates be 25bp cut AND Dissents be >0 for Jan 2026?
#   Volume:       $493,973.00
#   Liquidity:    $0.00
#   Duration:     48.2 days
#   Open Date:    2025-12-11
#   Close Date:   2026-01-28
#   Result:       NO (Winner(s): KXFEDCOMBO-26JAN-0-T0)
#   Event Type:   Multi-decision (4 option(s))
#
# ====================================================================================================
# Market #49
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDEMPLOYEES-26JAN-100000
#   Title:        Will there be more than 100000 government employees cut before Jan 2026?
#   Volume:       $473,151.00
#   Liquidity:    $-576.96
#   Duration:     399.0 days
#   Open Date:    2024-11-12
#   Close Date:   2025-12-16
#   Result:       YES (This option won)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #50
# ====================================================================================================
#   Category:     N/A
#   Ticker:       FED-25JUN-T4.50
#   Title:        Will the upper bound of the federal funds rate be above 4.50% following the Fed's Jun 18, 2025 meeting?
#   Volume:       $457,475.00
#   Liquidity:    $134.34
#   Duration:     301.2 days
#   Open Date:    2024-08-21
#   Close Date:   2025-06-18
#   Result:       NO (Winner(s): FED-25JUN-T4.25, FED-25JUN-T4.00, FED-25JUN-T3.75)
#   Event Type:   Multi-decision (11 option(s))
#
# ====================================================================================================
# Market #51
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXCBDECISIONJAPAN-26JAN22-H25
#   Title:        Will the Bank of Japan Hike 25 basis points at the Jan 2026 BOJ meeting?
#   Volume:       $456,449.00
#   Liquidity:    $0.00
#   Duration:     30.5 days
#   Open Date:    2025-12-23
#   Close Date:   2026-01-23
#   Result:       NO (Winner(s): KXCBDECISIONJAPAN-26JAN22-HOLD)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #52
# ====================================================================================================
#   Category:     N/A
#   Ticker:       FED-25OCT-T4.00
#   Title:        Will the upper bound of the federal funds rate be above 4.00% following the Fed's Oct 29, 2025 meeting?
#   Volume:       $426,779.00
#   Liquidity:    $26,910.84
#   Duration:     434.2 days
#   Open Date:    2024-08-21
#   Close Date:   2025-10-29
#   Result:       NO (Winner(s): FED-25OCT-T3.75, FED-25OCT-T3.50, FED-25OCT-T3.25)
#   Event Type:   Multi-decision (11 option(s))
#
# ====================================================================================================
# Market #53
# ====================================================================================================
#   Category:     N/A
#   Ticker:       FED-25SEP-T4.50
#   Title:        Will the upper bound of the federal funds rate be above 4.50% following the Fed's Sep 17, 2025 meeting?
#   Volume:       $389,905.00
#   Liquidity:    $0.00
#   Duration:     392.2 days
#   Open Date:    2024-08-21
#   Close Date:   2025-09-17
#   Result:       NO (Winner(s): FED-25SEP-T4.00, FED-25SEP-T3.75, FED-25SEP-T3.50)
#   Event Type:   Multi-decision (11 option(s))
#
# ====================================================================================================
# Market #54
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFED-26JAN-T3.50
#   Title:        Will the upper bound of the federal funds rate be above 3.50% following the Fed's Jan 28, 2026 meeting?
#   Volume:       $387,829.00
#   Liquidity:    $-432.93
#   Duration:     175.2 days
#   Open Date:    2025-08-06
#   Close Date:   2026-01-28
#   Result:       YES (This option won)
#   Event Type:   Multi-decision (11 option(s))
#
# ====================================================================================================
# Market #55
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXPRESNOMFEDCHAIR-25-26JAN15
#   Title:        Will Trump announce his new Chair of the Federal Reserve in 2026?
#   Volume:       $364,873.00
#   Liquidity:    $0.00
#   Duration:     43.4 days
#   Open Date:    2025-12-02
#   Close Date:   2026-01-15
#   Result:       NO (Winner(s): KXPRESNOMFEDCHAIR-25-26MAR16, KXPRESNOMFEDCHAIR-25-26MAR01, KXPRESNOMFEDCHAIR-25-26FEB15)
#   Event Type:   Multi-decision (10 option(s))
#
# ====================================================================================================
# Market #56
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDMENTION-26JAN-GOOD
#   Title:        Will Powell say Good Afternoon at his Jan 2026 press conference?
#   Volume:       $349,429.00
#   Liquidity:    $0.00
#   Duration:     48.9 days
#   Open Date:    2025-12-11
#   Close Date:   2026-01-28
#   Result:       YES (This option won)
#   Event Type:   Multi-decision (44 option(s))
#
# ====================================================================================================
# Market #57
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDDECISION-25MAR-C26
#   Title:        Will the Federal Reserve Cut rates by >25bps at their March 2025 meeting?
#   Volume:       $345,005.00
#   Liquidity:    $0.00
#   Duration:     49.1 days
#   Open Date:    2025-01-29
#   Close Date:   2025-03-19
#   Result:       NO (Winner(s): KXFEDDECISION-25MAR-H0)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #58
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDDECISION-25DEC-H25
#   Title:        Will the Federal Reserve Hike rates by 25bps at their December 2025 meeting?
#   Volume:       $308,409.00
#   Liquidity:    $993.92
#   Duration:     127.2 days
#   Open Date:    2025-08-05
#   Close Date:   2025-12-10
#   Result:       NO (Winner(s): KXFEDDECISION-25DEC-C25)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #59
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDMENTION-26JAN-TRUM
#   Title:        Will Powell say Trump at his Jan 2026 press conference?
#   Volume:       $305,506.00
#   Liquidity:    $0.00
#   Duration:     48.9 days
#   Open Date:    2025-12-11
#   Close Date:   2026-01-28
#   Result:       NO (Winner(s): KXFEDMENTION-26JAN-RENO, KXFEDMENTION-26JAN-SOFTE, KXFEDMENTION-26JAN-TRAD)
#   Event Type:   Multi-decision (44 option(s))
#
# ====================================================================================================
# Market #60
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDEMPLOYEES-26JAN-500000
#   Title:        Will there be more than 500000 government employees cut before Jan 2026?
#   Volume:       $290,665.00
#   Liquidity:    $188.71
#   Duration:     433.2 days
#   Open Date:    2024-11-12
#   Close Date:   2026-01-19
#   Result:       NO (Winner(s): KXFEDEMPLOYEES-26JAN-100000, KXFEDEMPLOYEES-26JAN-250000, KXFEDEMPLOYEES-26JAN-50000)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #61
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDDECISION-26JAN-H26
#   Title:        Will the Federal Reserve Hike rates by >25bps at their January 2026 meeting?
#   Volume:       $290,042.00
#   Liquidity:    $0.00
#   Duration:     121.2 days
#   Open Date:    2025-09-29
#   Close Date:   2026-01-28
#   Result:       NO (Winner(s): KXFEDDECISION-26JAN-H0)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #62
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDMENTION-26JAN-RENO
#   Title:        Will Powell say Renovation at his Jan 2026 press conference?
#   Volume:       $264,460.00
#   Liquidity:    $0.00
#   Duration:     15.3 days
#   Open Date:    2026-01-13
#   Close Date:   2026-01-28
#   Result:       YES (This option won)
#   Event Type:   Multi-decision (44 option(s))
#
# ====================================================================================================
# Market #63
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXPRESNOMFEDCHAIR-25-26JAN22
#   Title:        Will Trump announce his new Chair of the Federal Reserve in 2026?
#   Volume:       $251,873.00
#   Liquidity:    $0.00
#   Duration:     18.6 days
#   Open Date:    2026-01-03
#   Close Date:   2026-01-22
#   Result:       NO (Winner(s): KXPRESNOMFEDCHAIR-25-26MAR16, KXPRESNOMFEDCHAIR-25-26MAR01, KXPRESNOMFEDCHAIR-25-26FEB15)
#   Event Type:   Multi-decision (10 option(s))
#
# ====================================================================================================
# Market #64
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDMENTION-26JAN-PROJ
#   Title:        Will Powell say Projection at his Jan 2026 press conference?
#   Volume:       $249,930.00
#   Liquidity:    $0.00
#   Duration:     48.9 days
#   Open Date:    2025-12-11
#   Close Date:   2026-01-28
#   Result:       YES (This option won)
#   Event Type:   Multi-decision (44 option(s))
#
# ====================================================================================================
# Market #65
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDCOMBO-26JAN-0-0
#   Title:        Will Federal Funds Rates be No change AND Dissents be 0 for Jan 2026?
#   Volume:       $238,164.00
#   Liquidity:    $0.00
#   Duration:     48.2 days
#   Open Date:    2025-12-11
#   Close Date:   2026-01-28
#   Result:       NO (Winner(s): KXFEDCOMBO-26JAN-0-T0)
#   Event Type:   Multi-decision (4 option(s))
#
# ====================================================================================================
# Market #66
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXPRESNOMFEDCHAIR-25-26MAR01
#   Title:        Will Trump announce his new Chair of the Federal Reserve in 2026?
#   Volume:       $235,923.00
#   Liquidity:    $0.00
#   Duration:     13.9 days
#   Open Date:    2026-01-16
#   Close Date:   2026-01-30
#   Result:       YES (This option won)
#   Event Type:   Multi-decision (10 option(s))
#
# ====================================================================================================
# Market #67
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDDECISION-25JUN-H26
#   Title:        Will the Federal Reserve Hike rates by >25bps at their June 2025 meeting?
#   Volume:       $231,169.00
#   Liquidity:    $105.50
#   Duration:     42.2 days
#   Open Date:    2025-05-07
#   Close Date:   2025-06-18
#   Result:       NO (Winner(s): KXFEDDECISION-25JUN-H0)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #68
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXPOWELLMENTION-25OCT15-AI
#   Title:        What will Jerome Powell say during Speech At the National Association for Business Economics?
#   Volume:       $227,324.00
#   Liquidity:    $441.50
#   Duration:     3.9 days
#   Open Date:    2025-10-10
#   Close Date:   2025-10-14
#   Result:       YES (This option won)
#   Event Type:   Multi-decision (26 option(s))
#
# ====================================================================================================
# Market #69
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDMENTION-26JAN-GOLD
#   Title:        Will Powell say Gold at his Jan 2026 press conference?
#   Volume:       $224,980.00
#   Liquidity:    $0.00
#   Duration:     48.9 days
#   Open Date:    2025-12-11
#   Close Date:   2026-01-28
#   Result:       NO (Winner(s): KXFEDMENTION-26JAN-RENO, KXFEDMENTION-26JAN-SOFTE, KXFEDMENTION-26JAN-TRAD)
#   Event Type:   Multi-decision (44 option(s))
#
# ====================================================================================================
# Market #70
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDDECISION-25OCT-H25
#   Title:        Will the Federal Reserve Hike rates by 25bps at their October 2025 meeting?
#   Volume:       $221,464.00
#   Liquidity:    $0.00
#   Duration:     85.2 days
#   Open Date:    2025-08-05
#   Close Date:   2025-10-29
#   Result:       NO (Winner(s): KXFEDDECISION-25OCT-C25)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #71
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXCBDECISIONJAPAN-25DEC18-HOLD
#   Title:        Will the Bank of Japan Maintain current rate at the Dec 2025 BOJ meeting?
#   Volume:       $221,292.00
#   Liquidity:    $0.00
#   Duration:     40.5 days
#   Open Date:    2025-11-08
#   Close Date:   2025-12-19
#   Result:       NO (Winner(s): KXCBDECISIONJAPAN-25DEC18-H2140)
#   Event Type:   Multi-decision (7 option(s))
#
# ====================================================================================================
# Market #72
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFED-26JAN-T4.00
#   Title:        Will the upper bound of the federal funds rate be above 4.00% following the Fed's Jan 28, 2026 meeting?
#   Volume:       $219,801.00
#   Liquidity:    $-168.87
#   Duration:     175.2 days
#   Open Date:    2025-08-06
#   Close Date:   2026-01-28
#   Result:       NO (Winner(s): KXFED-26JAN-T3.50, KXFED-26JAN-T3.25, KXFED-26JAN-T3.00)
#   Event Type:   Multi-decision (11 option(s))
#
# ====================================================================================================
# Market #73
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDCOMBO-26JAN-25C-0
#   Title:        Will Federal Funds Rates be 25bp cut AND Dissents be 0 for Jan 2026?
#   Volume:       $215,509.00
#   Liquidity:    $0.00
#   Duration:     48.2 days
#   Open Date:    2025-12-11
#   Close Date:   2026-01-28
#   Result:       NO (Winner(s): KXFEDCOMBO-26JAN-0-T0)
#   Event Type:   Multi-decision (4 option(s))
#
# ====================================================================================================
# Market #74
# ====================================================================================================
#   Category:     N/A
#   Ticker:       FED-25MAR-T4.25
#   Title:        Will the upper bound of the federal funds rate be above 4.25% following the Fed's Mar 19, 2025 meeting?
#   Volume:       $204,160.00
#   Liquidity:    $0.00
#   Duration:     210.2 days
#   Open Date:    2024-08-21
#   Close Date:   2025-03-19
#   Result:       YES (This option won)
#   Event Type:   Multi-decision (11 option(s))
#
# ====================================================================================================
# Market #75
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDMENTION-26JAN-MEDI
#   Title:        Will Powell say Median at his Jan 2026 press conference?
#   Volume:       $203,908.00
#   Liquidity:    $0.00
#   Duration:     48.9 days
#   Open Date:    2025-12-11
#   Close Date:   2026-01-28
#   Result:       NO (Winner(s): KXFEDMENTION-26JAN-RENO, KXFEDMENTION-26JAN-SOFTE, KXFEDMENTION-26JAN-TRAD)
#   Event Type:   Multi-decision (44 option(s))
#
# ====================================================================================================
# Market #76
# ====================================================================================================
#   Category:     N/A
#   Ticker:       FED-25JUN-T4.00
#   Title:        Will the upper bound of the federal funds rate be above 4.00% following the Fed's Jun 18, 2025 meeting?
#   Volume:       $199,707.00
#   Liquidity:    $743.81
#   Duration:     301.2 days
#   Open Date:    2024-08-21
#   Close Date:   2025-06-18
#   Result:       YES (This option won)
#   Event Type:   Multi-decision (11 option(s))
#
# ====================================================================================================
# Market #77
# ====================================================================================================
#   Category:     N/A
#   Ticker:       FED-25OCT-T3.75
#   Title:        Will the upper bound of the federal funds rate be above 3.75% following the Fed's Oct 29, 2025 meeting?
#   Volume:       $197,440.00
#   Liquidity:    $1,226.11
#   Duration:     434.2 days
#   Open Date:    2024-08-21
#   Close Date:   2025-10-29
#   Result:       YES (This option won)
#   Event Type:   Multi-decision (11 option(s))
#
# ====================================================================================================
# Market #78
# ====================================================================================================
#   Category:     N/A
#   Ticker:       FED-25OCT-T4.25
#   Title:        Will the upper bound of the federal funds rate be above 4.25% following the Fed's Oct 29, 2025 meeting?
#   Volume:       $195,282.00
#   Liquidity:    $118.37
#   Duration:     434.2 days
#   Open Date:    2024-08-21
#   Close Date:   2025-10-29
#   Result:       NO (Winner(s): FED-25OCT-T3.75, FED-25OCT-T3.50, FED-25OCT-T3.25)
#   Event Type:   Multi-decision (11 option(s))
#
# ====================================================================================================
# Market #79
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDMENTION-25DEC-TRUM
#   Title:        Will Powell say Trump at his Dec 2025 press conference?
#   Volume:       $193,636.00
#   Liquidity:    $0.00
#   Duration:     40.9 days
#   Open Date:    2025-10-31
#   Close Date:   2025-12-10
#   Result:       NO (Winner(s): KXFEDMENTION-25DEC-LAYO, KXFEDMENTION-25DEC-TAX, KXFEDMENTION-25DEC-PAND)
#   Event Type:   Multi-decision (41 option(s))
#
# ====================================================================================================
# Market #80
# ====================================================================================================
#   Category:     N/A
#   Ticker:       FED-25MAY-T4.50
# ...
#   Duration:     2.1 days
#   Open Date:    2025-05-13
#   Close Date:   2025-05-15
#   Result:       NO (Winner(s): KXJPOWMENTION-25MAY15-FOMC, KXJPOWMENTION-25MAY15-ELB, KXJPOWMENTION-25MAY15-GMORN)
#   Event Type:   Multi-decision (20 option(s))
#
# ====================================================================================================
# Market #836
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDGOVMENTION-25NOV08-STOC
#   Title:        What will Philip Jefferson say during speech at Euro20+?
#   Volume:       $9.00
#   Liquidity:    $0.00
#   Duration:     2.8 days
#   Open Date:    2025-11-05
#   Close Date:   2025-11-07
#   Result:       NO (Winner(s): KXFEDGOVMENTION-25NOV08-AUTO, KXFEDGOVMENTION-25NOV08-CHAT, KXFEDGOVMENTION-25NOV08-MONE)
#   Event Type:   Multi-decision (11 option(s))
#
# ====================================================================================================
# Market #837
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXCBDECISIONAUSTRALIA-25DEC08-H25P
#   Title:        Will the Reserve Bank of Australia Hike more than 25bp at the Dec 2025 RBA meeting?
#   Volume:       $7.00
#   Liquidity:    $0.00
#   Duration:     30.5 days
#   Open Date:    2025-11-08
#   Close Date:   2025-12-09
#   Result:       NO (Winner(s): KXCBDECISIONAUSTRALIA-25DEC08-HOLD)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #838
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXDOTPLOT-25JUN-3.9
#   Title:        Will the median dot move up in the Fed's next 2024 dot plot?
#   Volume:       $5.00
#   Liquidity:    $0.00
#   Duration:     5.0 days
#   Open Date:    2025-06-13
#   Close Date:   2025-06-18
#   Result:       NO
#   Event Type:   Binary (1 option(s))
#
# ====================================================================================================
# Market #839
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXGOVAPPTCOUNT-26JAN01-3
#   Title:        Will Trump appoint at least 3 people to the Federal Reserve Board of Governors before Jan 1, 2026?
#   Volume:       $2.00
#   Liquidity:    $0.00
#   Duration:     128.3 days
#   Open Date:    2025-08-25
#   Close Date:   2026-01-01
#   Result:       NO (Multi-decision event, no clear winner found)
#   Event Type:   Multi-decision (4 option(s))
#
# ====================================================================================================
# Market #840
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXEARNINGSMENTIONFDX-25SEP18-COST
#   Title:        What will FedEx say during their next earnings call?
#   Volume:       $0.00
#   Liquidity:    $0.00
#   Duration:     2.1 days
#   Open Date:    2025-09-17
#   Close Date:   2025-09-19
#   Result:       YES (This option won)
#   Event Type:   Multi-decision (17 option(s))
#
# ====================================================================================================
# Market #841
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXCBDECISIONCHINA-25NOV19-H10P
#   Title:        Will the People's Bank of China Hike more than 10bp at the Nov 2025 PBOC meeting?
#   Volume:       $0.00
#   Liquidity:    $0.00
#   Duration:     10.3 days
#   Open Date:    2025-11-09
#   Close Date:   2025-11-20
#   Result:       NO (Winner(s): KXCBDECISIONCHINA-25NOV19-HOLD)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #842
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXCBDECISIONENGLAND-25DEC18-H25P
#   Title:        Will the Bank of England Hike more than 25bp at the Dec 2025 BOE meeting?
#   Volume:       $0.00
#   Liquidity:    $0.00
#   Duration:     39.9 days
#   Open Date:    2025-11-08
#   Close Date:   2025-12-18
#   Result:       NO (Winner(s): KXCBDECISIONENGLAND-25DEC18-C25)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #843
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXGOVAPPTCOUNT-26JAN01-5
#   Title:        Will Trump appoint at least 5 people to the Federal Reserve Board of Governors before Jan 1, 2026?
#   Volume:       $0.00
#   Liquidity:    $0.00
#   Duration:     128.3 days
#   Open Date:    2025-08-25
#   Close Date:   2026-01-01
#   Result:       NO (Multi-decision event, no clear winner found)
#   Event Type:   Multi-decision (4 option(s))
#
# ====================================================================================================
# Market #844
# ====================================================================================================
#   Category:     N/A
#   Ticker:       FED-25MAR-T5.25
#   Title:        Will the upper bound of the federal funds rate be above 5.25% following the Fed's Mar 19, 2025 meeting?
#   Volume:       $0.00
#   Liquidity:    $0.00
#   Duration:     210.2 days
#   Open Date:    2024-08-21
#   Close Date:   2025-03-19
#   Result:       NO (Winner(s): FED-25MAR-T4.25, FED-25MAR-T4.00, FED-25MAR-T3.75)
#   Event Type:   Multi-decision (11 option(s))
#
# ====================================================================================================
# Market #845
# ====================================================================================================
#   Category:     N/A
#   Ticker:       FED-25MAR-T5.00
#   Title:        Will the upper bound of the federal funds rate be above 5.00% following the Fed's Mar 19, 2025 meeting?
#   Volume:       $0.00
#   Liquidity:    $0.00
#   Duration:     210.2 days
#   Open Date:    2024-08-21
#   Close Date:   2025-03-19
#   Result:       NO (Winner(s): FED-25MAR-T4.25, FED-25MAR-T4.00, FED-25MAR-T3.75)
#   Event Type:   Multi-decision (11 option(s))
#
# ====================================================================================================
# Market #846
# ====================================================================================================
#   Category:     N/A
#   Ticker:       FED-25MAR-T3.00
#   Title:        Will the upper bound of the federal funds rate be above 3.00% following the Fed's Mar 19, 2025 meeting?
#   Volume:       $0.00
#   Liquidity:    $0.00
#   Duration:     210.2 days
#   Open Date:    2024-08-21
#   Close Date:   2025-03-19
#   Result:       YES (This option won)
#   Event Type:   Multi-decision (11 option(s))
#
# ====================================================================================================
# Market #847
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXCBDECISIONMEXICO-25DEC18-H25P
#   Title:        Will the Bank of Mexico Hike more than 25bp at the Dec 2025 BdeM meeting?
#   Volume:       $0.00
#   Liquidity:    $0.00
#   Duration:     40.2 days
#   Open Date:    2025-11-08
#   Close Date:   2025-12-18
#   Result:       NO (Winner(s): KXCBDECISIONMEXICO-25DEC18-C25)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #848
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXCBDECISIONCANADA-25OCT-H26
#   Title:        Will Bank of Canada Hike rates by >25bps at their October 2025 meeting?
#   Volume:       $0.00
#   Liquidity:    $0.00
#   Duration:     21.0 days
#   Open Date:    2025-10-08
#   Close Date:   2025-10-29
#   Result:       NO (Winner(s): KXCBDECISIONCANADA-25OCT-C25)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #849
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXCBDECISIONCANADA-25OCT-H25
#   Title:        Will Bank of Canada Hike rates by 25bps at their October 2025 meeting?
#   Volume:       $0.00
#   Liquidity:    $0.00
#   Duration:     21.0 days
#   Open Date:    2025-10-08
#   Close Date:   2025-10-29
#   Result:       NO (Winner(s): KXCBDECISIONCANADA-25OCT-C25)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
# Market #850
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXJPOWMENTION-25MAY15-DOTP
#   Title:        What will Jerome Powell say during Framework Review At the Thomas Laubach Research Conference originally scheduled for 8:40 AM ET?
#   Volume:       $0.00
#   Liquidity:    $0.00
#   Duration:     0.7 days
#   Open Date:    2025-05-14
#   Close Date:   2025-05-15
#   Result:       NO (Winner(s): KXJPOWMENTION-25MAY15-FOMC, KXJPOWMENTION-25MAY15-ELB, KXJPOWMENTION-25MAY15-GMORN)
#   Event Type:   Multi-decision (20 option(s))
#
# ====================================================================================================
# Market #851
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXJPOWMENTION-25MAY15-FLEX
#   Title:        What will Jerome Powell say during Framework Review At the Thomas Laubach Research Conference originally scheduled for 8:40 AM ET?
#   Volume:       $0.00
#   Liquidity:    $9.02
#   Duration:     2.1 days
#   Open Date:    2025-05-13
#   Close Date:   2025-05-15
#   Result:       NO (Winner(s): KXJPOWMENTION-25MAY15-FOMC, KXJPOWMENTION-25MAY15-ELB, KXJPOWMENTION-25MAY15-GMORN)
#   Event Type:   Multi-decision (20 option(s))
#
# ====================================================================================================
# Market #852
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXJPOWMENTION-25MAY15-TRANS
#   Title:        What will Jerome Powell say during Framework Review At the Thomas Laubach Research Conference originally scheduled for 8:40 AM ET?
#   Volume:       $0.00
#   Liquidity:    $0.00
#   Duration:     2.1 days
#   Open Date:    2025-05-13
#   Close Date:   2025-05-15
#   Result:       NO (Winner(s): KXJPOWMENTION-25MAY15-FOMC, KXJPOWMENTION-25MAY15-ELB, KXJPOWMENTION-25MAY15-GMORN)
#   Event Type:   Multi-decision (20 option(s))
#
# ====================================================================================================
# Market #853
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDRATEMIN-25DEC31-T3.50
#   Title:        Will the Federal Reserve cut rates below 3.50%?
#   Volume:       $0.00
#   Liquidity:    $0.00
#   Duration:     412.1 days
#   Open Date:    2024-11-05
#   Close Date:   2025-12-22
#   Result:       NO (Multi-decision event, no clear winner found)
#   Event Type:   Multi-decision (3 option(s))
#
# ====================================================================================================
# Market #854
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDRATEMIN-25DEC31-T0.50
#   Title:        Will the Federal Reserve cut rates below 0.50%?
#   Volume:       $0.00
#   Liquidity:    $0.00
#   Duration:     412.1 days
#   Open Date:    2024-11-05
#   Close Date:   2025-12-22
#   Result:       NO (Multi-decision event, no clear winner found)
#   Event Type:   Multi-decision (3 option(s))
#
# ====================================================================================================
# Market #855
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDRATEMIN-25DEC31-T4.00
#   Title:        Will the Federal Reserve cut rates below 4.00%?
#   Volume:       $0.00
#   Liquidity:    $0.00
#   Duration:     412.1 days
#   Open Date:    2024-11-05
#   Close Date:   2025-12-22
#   Result:       NO (Multi-decision event, no clear winner found)
#   Event Type:   Multi-decision (3 option(s))
#
# ====================================================================================================
# Market #856
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXFEDFACILITY-25
#   Title:        New emergency Fed lending program in 2025?
#   Volume:       $0.00
#   Liquidity:    $0.00
#   Duration:     412.1 days
#   Open Date:    2024-11-05
#   Close Date:   2025-12-22
#   Result:       NO
#   Event Type:   Binary (1 option(s))
#
# ====================================================================================================
# Market #857
# ====================================================================================================
#   Category:     N/A
#   Ticker:       KXCBDECISIONKOREA-25NOV26-H25P
#   Title:        Will the Bank of Korea Hike more than 25bp at the Nov 2025 BOK meeting?
#   Volume:       $0.00
#   Liquidity:    $0.00
#   Duration:     17.3 days
#   Open Date:    2025-11-09
#   Close Date:   2025-11-26
#   Result:       NO (Winner(s): KXCBDECISIONKOREA-25NOV26-HOLD)
#   Event Type:   Multi-decision (5 option(s))
#
# ====================================================================================================
#
# SUMMARY STATISTICS
# ====================================================================================================
#   Total markets:     857
#   Average volume:    $460,479.09
#   Average duration:  65.3 days
#   Total volume:      $394,630,583.00
#
#   Category Distribution:
#     N/A: 857 markets
#
#   Result Distribution:
#     no: 565 markets
#     yes: 292 markets
#
#   Market Types:
#     Multi-decision: 839
#     Binary: 18
#
# ====================================================================================================
# TOP 10 BY VOLUME
# ====================================================================================================
#
#   1. KXFEDDECISION-25SEP-H0
#      Volume: $42,718,863.00
#      Title: Will the Federal Reserve Hike rates by 0bps at their September 2025 meeting?
#
#   2. KXFEDDECISION-25SEP-C26
#      Volume: $29,261,331.00
#      Title: Will the Federal Reserve Cut rates by >25bps at their September 2025 meeting?
#
#   3. KXFEDDECISION-25JUL-C25
#      Volume: $20,535,325.00
#      Title: Will the Federal Reserve Cut rates by 25bps at their July 2025 meeting?
#
#   4. KXFEDDECISION-26JAN-C25
#      Volume: $18,466,757.00
#      Title: Will the Federal Reserve Cut rates by 25bps at their January 2026 meeting?
#
#   5. KXFEDDECISION-25SEP-C25
#      Volume: $18,168,848.00
#      Title: Will the Federal Reserve Cut rates by 25bps at their September 2025 meeting?
#
#   6. KXFEDDECISION-25MAY-C25
#      Volume: $17,739,576.00
#      Title: Will the Federal Reserve Cut rates by 25bps at their May 2025 meeting?
#
#   7. KXFEDDECISION-25JUN-C25
#      Volume: $17,062,008.00
#      Title: Will the Federal Reserve Cut rates by 25bps at their June 2025 meeting?
#
#   8. KXFEDDECISION-25DEC-H0
#      Volume: $15,760,947.00
#      Title: Will the Federal Reserve Hike rates by 0bps at their December 2025 meeting?
#
#   9. KXFEDDECISION-25OCT-H0
#      Volume: $15,137,495.00
#      Title: Will the Federal Reserve Hike rates by 0bps at their October 2025 meeting?
#
#   10. KXFEDDECISION-25JUL-H0
#      Volume: $15,032,203.00
#      Title: Will the Federal Reserve Hike rates by 0bps at their July 2025 meeting?
# ====================================================================================================
